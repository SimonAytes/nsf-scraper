# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import sqlite3

# %%
# Capture URL
url = 'https://nsf.gov/awardsearch/showAward?AWD_ID=1735194'
# Request HTML from URL
r = requests.get(url)
# Parse HTML
soup = BeautifulSoup(r.text, 'html.parser')

# %%
for p in soup.find_all("p"):
    for strong in soup.find_all("strong"):
        if strong.text == "ABSTRACT":
        #if "Award Abstract #" in strong.text:
            print(p.text)
            print("*********************")
# Out:
# Award Abstract # 1735194
#
# Echo Chambers in Science?  The Impact of Academic Recommender Systems on the Dissemination of Scientific Knowledge
#
#
# *********************
#
# ABSTRACT
#
# ...
